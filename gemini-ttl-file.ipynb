# %% [markdown]
# ## TTL 파일 Gemini 테스트
#
# [TTL 파일 다운로드 경로](https://www.kaggle.com/code/mpwolke/another-ttl-turtle-file-on-the-wall/input)

# %%
# %pip install --upgrade --quiet google-genai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

PROJECT_ID = "kevin-ai-playground"  # @param {type: "string"}
LOCATION = "global" # @param {type: "string"}

from google import genai

client = genai.Client(vertexai=True, project=PROJECT_ID, location=LOCATION)

# %%
MODEL_ID = "gemini-2.5-flash"  # @param {type: "string"}

# %%
from IPython.display import Markdown, display
from google.genai.types import (
    ApiKeyConfig,
    AuthConfig,
    EnterpriseWebSearch,
    GenerateContentConfig,
    GenerateContentResponse,
    GoogleMaps,
    GoogleSearch,
    LatLng,
    Part,
    Retrieval,
    RetrievalConfig,
    Tool,
    ToolConfig,
    ToolCodeExecution,
    VertexAISearch,
)

# %%
ttl_file = Part.from_uri(
    file_uri="gs://kevin-vertexai-002/Brick (1).ttl",
    mime_type="text/tutle",
)

# %%
prompt1 = """
TTL 파일을 정리해서 간략하게 설명해줘. 
"""

# %%
response = client.models.generate_content(
    model=MODEL_ID,
    contents=[ttl_file, prompt1],
)

# %%
print(response.text)
# Out:
# 이 TTL(Turtle) 파일은 **Brick Schema**의 일부를 정의하고 있습니다. Brick Schema는 건물 내의 장비, 위치, 시스템 및 센서 데이터를 표준화하기 위한 온톨로지입니다.
#
# 다음은 이 파일의 주요 구성 요소와 그 역할에 대한 간략한 요약입니다.
#
# ---
#
# ### **Brick Schema TTL 파일 요약**
#
# 이 파일은 건물 자동화 및 관리 시스템에서 데이터를 표현하고 상호 운용성을 달성하기 위한 온톨로지인 Brick Schema의 정의를 포함합니다. 주로 클래스, 속성, 측정 단위 및 데이터 유효성 검사 규칙을 정의합니다.
#
# **1. 주요 접두사 (Prefixes):**
# *   **`brick:`**: Brick Schema의 핵심 요소 (클래스, 속성, 수량).
# *   **`bsh:`**: Brick Shape (Brick Schema SHACL). 데이터 유효성 검사 규칙.
# *   **`owl:`**: OWL Web Ontology Language. 클래스 계층, 속성 정의, 동등성 등을 정의.
# *   **`rdfs:`**: RDF Schema. 클래스, 서브클래스, 속성, 라벨, 정의 등을 정의.
# *   **`skos:`**: Simple Knowledge Organization System. 정의, 더 넓은/좁은 개념 등을 제공.
# *   **`tag:`**: Brick Tag. Brick 클래스를 구성하는 데 사용되는 원자적인 태그.
# *   **`qudt:` / `unit:`**: Quantity, Unit, Dimension Type. 측정 단위와 수량 종류를 정의하고 Brick의 수량과 연결.
# *   **`sh:`**: SHACL Shapes. 데이터 유효성 검사 규칙을 정의하는 데 사용.
#
# **2. 핵심 개념 (Classes):**
# ...

# %%
print(response.usage_metadata.prompt_tokens_details)
# Out:
# [ModalityTokenCount(
#   modality=<MediaModality.TEXT: 'TEXT'>,
#   token_count=206424
# )]
